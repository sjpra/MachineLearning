# %%
import numpy as np

# %%
import pandas as pd

# %%
df_train = pd.read_csv("train.csv")

# %%
df_test = pd.read_csv("test.csv")

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
#Number of missing values in each of the columns in Train data set
df_train.isnull().sum()

#Most missing values are present in Age and Cabin
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#Number of missing values in each of the columns in Test data set
df_test.isnull().sum()

#Most missing values in Age and Cabin
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
#Just the data frame for Missing Values in train data set
train_age_missing = df_train[df_train.Age.isnull()]

# %%
train_embark_missing = df_train[df_train.Embarked.isnull()]
train_embark_missing
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
#filling missing values for Embarked to use it
df_newtrain.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
def change(Embarked):
    return Embarked.fillna('S')

# %%
df_newtrain['Embarked'] = df_newtrain['Embarked'].transform(change)

# %%
df_newtrain.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
df_s_train = df_newtrain.replace('S',0)

# %%
df_s_test = df_newtest.replace('S',0)

# %%
df_s_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df_c_train = df_s_train.replace('C',1)

# %%
df_c_test = df_s_test.replace('C',1)

# %%
df_c_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df_q_train = df_c_train.replace('Q',2)

# %%
df_q_test = df_c_test.replace('Q',2)

# %%
df_q_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df_trainf = df_q_train

# %%
df_testf = df_q_test

# %%
train_age_missing
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
df_train.shape
# Out:
# (891, 12)

# %%
df_test.shape
# Out:
# (418, 11)

# %%
df_train.shape
# Out:
# (891, 12)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
df_train_male = df_train.replace('male',1)

# %%
df_test_male = df_test.replace('male',1)

# %%
df_train_female = df_train_male.replace('female', 0)

# %%
df_test_female = df_test_male.replace('female', 0)

# %%
df_newtrain = df_train_female

# %%
df_newtest = df_test_female

# %%
sns.heatmap(df_trainf.corr())

# %%
#We see that there is negative correlation between Pclass, Sex and Survival

# %%
df_trainf.head()
df_trainf.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex              int64
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked         int64
# dtype: object

# %%
df_testf.head()
df_testf.dtypes
# Out:
# PassengerId      int64
# Pclass           int64
# Name            object
# Sex              int64
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked         int64
# dtype: object

# %%
sns.jointplot(x='Sex', y='Survived', data =df_trainf, kind = 'kde')

# %%
sns.jointplot(x='Pclass', y='Survived', data =df_trainf, kind = 'kde')

# %%
sns.barplot(x='Sex',y='Survived',data =df_trainf)

# %%
sns.barplot(x='Pclass',y='Survived',data =df_trainf)

# %%
sns.barplot(x='Age',y='Survived',data =df_trainf)

# %%
sns.boxplot(x="Sex", y="Survived",data =df_trainf ,palette='rainbow')

# %%
#Lets deal with missing values now as we have seen that there are a number of missing values present

# %%
#we will impute missing values on the basis of mean for the missing values after grouping. 
#this was done before I converted the Embarked values hence is done with "df_newtrain" however the regression is done with "df_trainf"

# %%
df_newtrain.groupby(['Sex','Pclass'])['Age'].mean()
# Out:
# Sex  Pclass
# 0    1         34.786517
#      2         28.440789
#      3         22.081693
# 1    1         41.781913
#      2         30.751078
#      3         27.573988
# Name: Age, dtype: float64

# %%
df_newtest.groupby(['Sex','Pclass'])['Age'].mean()
# Out:
# Sex  Pclass
# 0    1         27.142512
#      2         32.235433
#      3         29.409342
# 1    1         29.441524
#      2         27.919823
#      3         28.962704
# Name: Age, dtype: float64

# %%
def add(age):
    return age.fillna(age.mean())

# %%
df_newtrain['Age'] = df_newtrain.groupby(['Pclass','Sex'])['Age'].transform(add)

# %%
df_newtest['Age'] = df_newtrain.groupby(['Pclass','Sex'])['Age'].transform(add)

# %%
#Cheking the Nulls present in Sex
df_trainf.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
#Cheking the Nulls present in Sex
df_testf.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
#filling the missing value in Fare in test
def change_fare(fare):
    return fare.fillna(fare.mean())

# %%
df_testf['Fare'] = df_testf['Fare'].transform(change_fare)

# %%
#Cheking the Nulls present in Sex
df_testf.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df_trainf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null int64
# Age            891 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       891 non-null int64
# dtypes: float64(2), int64(7), object(3)
# memory usage: 83.6+ KB

# %%
X_train = df_trainf.loc[:,['Age','Sex','Pclass']]
X_test = df_testf.loc[:,['Age','Sex','Pclass']]

# %%
Y_train = df_trainf['Survived']

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=500)
rf.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
Y_prediction = rf.predict(X_test)

# %%
submission = pd.DataFrame({ "PassengerId" : df_testf["PassengerId"], "Survived" : Y_prediction })

# %%
submission.to_csv("titanic_sonic_Kaggle.csv",index= False)
